# %%
from kafka import KafkaConsumer
import json

# %%
consumer = KafkaConsumer(
    'health_data_predicted',
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='latest',
    enable_auto_commit=True,
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)
for message in consumer:
    print(message)
# Out:
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=36, timestamp=1675097021047, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 24, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 0, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 8, 'Education': 4, 'Income': 3, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=37, timestamp=1675097028215, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 1, 'CholCheck': 1, 'BMI': 24, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 10, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 8, 'Education': 6, 'Income': 4, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=38, timestamp=1675097035553, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 26, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 3, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=39, timestamp=1675097041598, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 0, 'BMI': 21, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 1, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 4, 'PhysHlth': 0, 'DiffWalk': 1, 'Sex': 0, 'Age': 13, 'Education': 6, 'Income': 5, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=40, timestamp=1675097047443, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 0, 'CholCheck': 1, 'BMI': 34, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 1, 'GenHlth': 3, 'MentHlth': 10, 'PhysHlth': 10, 'DiffWalk': 0, 'Sex': 0, 'Age': 6, 'Education': 3, 'Income': 3, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=345, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=41, timestamp=1675097053790, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 42, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 1, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 0, 'PhysHlth': 4, 'DiffWalk': 0, 'Sex': 0, 'Age': 6, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=42, timestamp=1675097060416, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 25, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 1, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 13, 'Education': 5, 'Income': 4, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=43, timestamp=1675097067278, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 0, 'CholCheck': 1, 'BMI': 23, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 1, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 13, 'Education': 5, 'Income': 2, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=44, timestamp=1675097072836, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 24, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 0, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 2, 'DiffWalk': 0, 'Sex': 0, 'Age': 4, 'Education': 6, 'Income': 6, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=45, timestamp=1675097078963, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 1, 'CholCheck': 0, 'BMI': 29, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 9, 'Education': 5, 'Income': 5, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=46, timestamp=1675097085015, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 22, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 1, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 12, 'Education': 4, 'Income': 7, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=47, timestamp=1675097090550, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 1, 'CholCheck': 1, 'BMI': 20, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 1, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 9, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=48, timestamp=1675097096514, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 23, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 5, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 10, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=49, timestamp=1675097102964, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 24, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 5, 'MentHlth': 30, 'PhysHlth': 30, 'DiffWalk': 1, 'Sex': 1, 'Age': 5, 'Education': 4, 'Income': 1, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=345, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=50, timestamp=1675097109256, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 0, 'CholCheck': 1, 'BMI': 23, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 13, 'Education': 6, 'Income': 6, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=51, timestamp=1675097115824, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 26, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 1, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 2, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 2, 'Education': 5, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=52, timestamp=1675097122143, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 1, 'CholCheck': 1, 'BMI': 22, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 0, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 0, 'PhysHlth': 2, 'DiffWalk': 0, 'Sex': 1, 'Age': 9, 'Education': 6, 'Income': 7, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=53, timestamp=1675097129439, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 0, 'CholCheck': 0, 'BMI': 28, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 0, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 10, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 7, 'Education': 3, 'Income': 1, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=54, timestamp=1675097135596, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 32, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 1, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 9, 'Education': 6, 'Income': 6, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=55, timestamp=1675097141300, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 0, 'CholCheck': 1, 'BMI': 26, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 1, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 4, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 1, 'Sex': 0, 'Age': 13, 'Education': 4, 'Income': 7, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=56, timestamp=1675097147190, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 36, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 0, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 4, 'MentHlth': 25, 'PhysHlth': 14, 'DiffWalk': 0, 'Sex': 0, 'Age': 2, 'Education': 6, 'Income': 3, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=345, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=57, timestamp=1675097153218, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 26, 'Smoker': 1, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 0, 'PhysHlth': 7, 'DiffWalk': 0, 'Sex': 1, 'Age': 10, 'Education': 6, 'Income': 6, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=58, timestamp=1675097159369, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 0, 'CholCheck': 1, 'BMI': 26, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 1, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 11, 'Education': 5, 'Income': 5, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=59, timestamp=1675097165328, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 25, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 1, 'MentHlth': 15, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 5, 'Education': 4, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=60, timestamp=1675097171144, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 35, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 0, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 0, 'PhysHlth': 30, 'DiffWalk': 1, 'Sex': 0, 'Age': 12, 'Education': 5, 'Income': 3, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=345, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=61, timestamp=1675097177482, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 27, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 2, 'Education': 6, 'Income': 6, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=62, timestamp=1675097183773, timestamp_type=0, key=None, value={'HighBP': 1, 'HighChol': 1, 'CholCheck': 1, 'BMI': 25, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 3, 'MentHlth': 5, 'PhysHlth': 10, 'DiffWalk': 0, 'Sex': 1, 'Age': 8, 'Education': 6, 'Income': 4, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=63, timestamp=1675097191084, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 0, 'BMI': 31, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 0, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 5, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=64, timestamp=1675097198695, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 42, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 0, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 0, 'NoDocbcCost': 1, 'GenHlth': 3, 'MentHlth': 1, 'PhysHlth': 30, 'DiffWalk': 1, 'Sex': 1, 'Age': 5, 'Education': 5, 'Income': 4, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=344, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=65, timestamp=1675097205740, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 21, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 0, 'Age': 3, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ConsumerRecord(topic='health_data_predicted', partition=0, offset=66, timestamp=1675097211605, timestamp_type=0, key=None, value={'HighBP': 0, 'HighChol': 0, 'CholCheck': 1, 'BMI': 27, 'Smoker': 0, 'Stroke': 0, 'HeartDiseaseorAttack': 0, 'PhysActivity': 1, 'Fruits': 1, 'Veggies': 1, 'HvyAlcoholConsump': 0, 'AnyHealthcare': 1, 'NoDocbcCost': 0, 'GenHlth': 2, 'MentHlth': 0, 'PhysHlth': 0, 'DiffWalk': 0, 'Sex': 1, 'Age': 5, 'Education': 6, 'Income': 8, 'Diabetes_012': 0}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=343, serialized_header_size=-1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 8>()
#       1 consumer = KafkaConsumer(
#       2     'health_data_predicted',
#       3     bootstrap_servers=['localhost:9092'],
#    (...)
#       6     value_deserializer=lambda x: json.loads(x.decode('utf-8'))
#       7 )
# ----> 8 for message in consumer:
#       9     print(message)
#
# File E:\Anaconda\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File E:\Anaconda\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File E:\Anaconda\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File E:\Anaconda\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File E:\Anaconda\lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File E:\Anaconda\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File E:\Anaconda\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File E:\Anaconda\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File E:\Anaconda\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
